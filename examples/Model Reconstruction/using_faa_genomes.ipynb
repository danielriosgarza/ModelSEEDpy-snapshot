# %%
#clone all the genomes data

# !git clone https://github.com/Shinzen31/genomes.git

# -*- coding: utf-8 -*-

########################################
# 1. Environment Setup and Dependency Installation (can be executed in Colab)
########################################
# !pip install -q gurobipy cobra modelseedpy pyrodigal biopython

import warnings
from sklearn.exceptions import InconsistentVersionWarning
warnings.filterwarnings("ignore", category=InconsistentVersionWarning)

import os, glob, gzip, shutil, re

# Configure the Gurobi license (please replace with your own WLSACCESSID, WLSSECRET, LICENSEID)
WLSACCESSID = "9cff747c-69bf-432f-8a5e-626093428473"
WLSSECRET   = "94a4f3c2-913b-4777-ad5a-9d9598a0f84c"
LICENSEID   = "2646038"

os.makedirs("/content/licenses", exist_ok=True)
gurobi_lic_text = f"""# Gurobi WLS license file
WLSACCESSID={WLSACCESSID}
WLSSECRET={WLSSECRET}
LICENSEID={LICENSEID}
"""
with open("/content/licenses/gurobi.lic", "w") as f:
    f.write(gurobi_lic_text)
os.environ["GRB_LICENSE_FILE"] = "/content/licenses/gurobi.lic"

import gurobipy
print("Gurobi ready!")

import cobra
try:
    test_m = cobra.io.load_model("textbook")
    sol = test_m.optimize()
    print("COBRApy ok! textbook obj =", sol.objective_value)
except Exception as e:
    print("COBRApy fallback test:", e)
# Out:
# Cloning into 'genomes'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 50 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 21.58 MiB | 21.69 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 256.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.6/467.6 kB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 72.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 69.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 32.4 MB/s eta 0:00:00
#   Building wheel for chemw (setup.py) ... done
#   Building wheel for pubchempy (setup.py) ... done
# Gurobi ready!
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2646038
# Academic license 2646038 - for non-commercial use only - registered to ch___@outlook.fr
# COBRApy ok! textbook obj = 0.8739215069684305

# %% [markdown]
# **Data file format conversion and draft model construction**

# %%
########################################
# 2. fna(.gz) → faa (using Pyrodigal)
########################################
import pyrodigal
from Bio import SeqIO

def convert_fna_to_faa(fna_file, faa_file):
    """
    Perform ORF prediction using the metagenomic mode of Pyrodigal and generate a .faa file
    """
    if fna_file.lower().endswith(".gz"):
        handle = gzip.open(fna_file, "rt")
    else:
        handle = open(fna_file, "r")
    recs = list(SeqIO.parse(handle, "fasta"))
    handle.close()

    gf = pyrodigal.GeneFinder(meta=True)
    with open(faa_file, "w") as fout:
        for rec in recs:
            genes = gf.find_genes(str(rec.seq))
            genes.write_translations(fout, sequence_id=rec.id)

    print(f"[Done] {fna_file} -> {faa_file}")


def gunzip_faa(faa_gz, faa_out):
    """
    Decompress a .faa.gz file to .faa
    """
    with gzip.open(faa_gz, "rt") as zf, open(faa_out, "w") as out_f:
        out_f.write(zf.read())
    print(f"[Decompressed] {faa_gz} -> {faa_out}")


########################################
# 3. Batch Build Draft Models (without ID repair / without adding biomass)
########################################
from modelseedpy import MSBuilder, MSGenome

# Create output directory
models_dir = "/content/models"
os.makedirs(models_dir, exist_ok=True)

genomes_dir = "/content/genomes"
# Collect all input files (fna, fna.gz, faa, faa.gz)
input_files = sorted(glob.glob(os.path.join(genomes_dir, "*.fna"))) + \
              sorted(glob.glob(os.path.join(genomes_dir, "*.fna.gz"))) + \
              sorted(glob.glob(os.path.join(genomes_dir, "*.faa"))) + \
              sorted(glob.glob(os.path.join(genomes_dir, "*.faa.gz")))

print(f"Found {len(input_files)} input genomes in {genomes_dir}.")

for input_file in input_files:
    # Extract model name (remove path and extension, used for model.id and output file name)
    filename = os.path.basename(input_file)
    base_name = filename
    if filename.endswith(".gz"):
        base_name = base_name[:-3]  # Remove .gz
    if base_name.endswith(".fna") or base_name.endswith(".faa"):
        base_name = base_name[:-4]  # Remove .fna or .faa

    # Default path for generated/used .faa file
    faa_path = os.path.join("/content", base_name + ".faa")

    # If the input is fna or fna.gz, perform ORF prediction first
    if input_file.endswith(".fna") or input_file.endswith(".fna.gz"):
        convert_fna_to_faa(input_file, faa_path)
    # If the input is .faa.gz, decompress it to .faa
    elif input_file.endswith(".faa.gz"):
        gunzip_faa(input_file, faa_path)
    else:
        # If it is already .faa, no further processing is required
        faa_path = input_file

    # Use ModelSEEDpy to build the draft model
    ms_genome = MSGenome.from_fasta(faa_path, split=' ')

    try:
        model = MSBuilder.build_metabolic_model(
            model_id=base_name,
            genome=ms_genome,
            index="0",
            gapfill_model=False,
            gapfill_media=None,
            annotate_with_rast=True,           # Note: Requires RAST credentials
            allow_all_non_grp_reactions=True
        )
    except Exception as e:
        print(f"[Error] Model construction failed: {input_file} => {e}")
        continue

    # Do not perform ID repair, and do not add the biomass (bio1) reaction
    # model.id = base_name  # Only set model.id to base_name

    # Save the model
    sbml_path = os.path.join(models_dir, base_name + ".xml")
    cobra.io.write_sbml_model(model, sbml_path)


print("\nAll draft models built.")
# Out:
# modelseedpy 0.4.2
# Found 40 input genomes in /content/genomes.
# [Done] /content/genomes/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.fna.gz -> /content/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.faa
# WARNING:modelseedpy.helpers:mkdir: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/ml
# WARNING:modelseedpy.helpers:downloading data file to: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/ml/knn_ACNP_RAST_filter_01_17_2023.pickle
# WARNING:modelseedpy.helpers:downloading data file to: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/ml/knn_ACNP_RAST_filter_01_17_2023_features.json
# WARNING:modelseedpy.helpers:mkdir: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/templates
# WARNING:modelseedpy.helpers:downloading data file to: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/templates/template_gram_pos.json
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# [Done] /content/genomes/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.fna.gz -> /content/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# WARNING:modelseedpy.helpers:downloading data file to: /usr/local/lib/python3.11/dist-packages/modelseedpy//data/templates/template_gram_neg.json
# [Done] /content/genomes/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.fna.gz -> /content/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_000010425.1_ASM1042v1_protein.faa.gz -> /content/GCF_000010425.1_ASM1042v1_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.faa.gz -> /content/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.faa.gz -> /content/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.faa.gz -> /content/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.faa.gz -> /content/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.faa.gz -> /content/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.faa.gz -> /content/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.faa.gz -> /content/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.faa.gz -> /content/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.faa.gz -> /content/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.faa.gz -> /content/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.faa.gz -> /content/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.faa.gz -> /content/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.faa.gz -> /content/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.faa.gz -> /content/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.faa.gz -> /content/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.faa.gz -> /content/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.faa.gz -> /content/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.faa.gz -> /content/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063415.1_Latilactobacillus_sakei_J33_protein.faa.gz -> /content/GCF_964063415.1_Latilactobacillus_sakei_J33_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.faa.gz -> /content/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.faa.gz -> /content/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.faa.gz -> /content/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.faa.gz -> /content/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.faa.gz -> /content/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.faa.gz -> /content/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.faa.gz -> /content/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.faa.gz -> /content/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.faa.gz -> /content/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.faa.gz -> /content/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.faa.gz -> /content/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.faa.gz -> /content/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.faa.gz -> /content/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.faa.gz -> /content/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.faa.gz -> /content/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.faa.gz -> /content/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# [Decompressed] /content/genomes/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.faa.gz -> /content/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.faa
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# All draft models built.

# %% [markdown]
# **Draft model infomation print（Facilitates the identification of oxygen-related metabolites.）**

# %%
import os
import cobra

models_dir = "/content/models"  # The folder contains 39 models
model_files = sorted([f for f in os.listdir(models_dir) if f.endswith(".xml")])

for filename in model_files:
    model_path = os.path.join(models_dir, filename)
    try:
        model = cobra.io.read_sbml_model(model_path)
    except Exception as e:
        print(f"Error loading model {filename}: {e}")
        continue

    print(f"\n------ Model: {filename} (ID: {model.id}) ------")
    for metabolite in model.metabolites:
        reacStr = metabolite.name.lower()
        if 'o2' in reacStr:
            print(metabolite.name, reacStr, metabolite.id)
        if 'oxygen' in reacStr:
            print(metabolite.name, reacStr, metabolite.id)
# Out:
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# kdo2-lipid a [c0] kdo2-lipid a [c0] cpd03587_c0
# heptosyl-kdo2-lipidA [c0] heptosyl-kdo2-lipida [c0] cpd15485_c0
# kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15492_c0
# phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15549_c0
# heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15488_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Lauroyl-KDO2-lipid IV(A) [c0] lauroyl-kdo2-lipid iv(a) [c0] cpd03736_c0
# heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-heptosyl-kdo2-lipida [c0] cpd15484_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# kdo2-lipid iva [c0] kdo2-lipid iva [c0] cpd03586_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_000010425.1_ASM1042v1_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# O2 [e0] o2 [e0] cpd00007_e0
# O2 [c0] o2 [c0] cpd00007_c0
# CO2 [e0] co2 [e0] cpd00011_e0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.xml (ID: ) ------
# heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15488_c0
# phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15550_c0
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# kdo2-lipid a [c0] kdo2-lipid a [c0] cpd03587_c0
# heptosyl-kdo2-lipidA [c0] heptosyl-kdo2-lipida [c0] cpd15485_c0
# heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-heptosyl-kdo2-lipida [c0] cpd15484_c0
# phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15549_c0
# kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15492_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Lauroyl-KDO2-lipid IV(A) [c0] lauroyl-kdo2-lipid iv(a) [c0] cpd03736_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# kdo2-lipid iva [c0] kdo2-lipid iva [c0] cpd03586_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.xml (ID: ) ------
# heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15488_c0
# phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15550_c0
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# kdo2-lipid a [c0] kdo2-lipid a [c0] cpd03587_c0
# heptosyl-kdo2-lipidA [c0] heptosyl-kdo2-lipida [c0] cpd15485_c0
# heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-heptosyl-kdo2-lipida [c0] cpd15484_c0
# phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15549_c0
# kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipidA [c0] kdo-phospho-heptosyl-phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15492_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Lauroyl-KDO2-lipid IV(A) [c0] lauroyl-kdo2-lipid iv(a) [c0] cpd03736_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# kdo2-lipid iva [c0] kdo2-lipid iva [c0] cpd03586_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# kdo2-lipid a [c0] kdo2-lipid a [c0] cpd03587_c0
# heptosyl-kdo2-lipidA [c0] heptosyl-kdo2-lipida [c0] cpd15485_c0
# heptosyl-heptosyl-kdo2-lipidA [c0] heptosyl-heptosyl-kdo2-lipida [c0] cpd15484_c0
# phospho-heptosyl-heptosyl-kdo2-lipidA [c0] phospho-heptosyl-heptosyl-kdo2-lipida [c0] cpd15549_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# Lauroyl-KDO2-lipid IV(A) [c0] lauroyl-kdo2-lipid iv(a) [c0] cpd03736_c0
# kdo2-lipid iva [c0] kdo2-lipid iva [c0] cpd03586_c0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063415.1_Latilactobacillus_sakei_J33_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# O2- [c0] o2- [c0] cpd00532_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
#
# ------ Model: GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.xml (ID: ) ------
# CO2 [c0] co2 [c0] cpd00011_c0
# O2 [c0] o2 [c0] cpd00007_c0
# H2O2 [c0] h2o2 [c0] cpd00025_c0
# Co2+ [c0] co2+ [c0] cpd00149_c0
# Co2+ [e0] co2+ [e0] cpd00149_e0
# O2 [e0] o2 [e0] cpd00007_e0
# CO2 [e0] co2 [e0] cpd00011_e0

# %% [markdown]
# **Construct a complete medium and print the list of oxygen-related reactions for each draft model.**

# %%
import os
import cobra
import re

# Define your model directory that contains 39 draft models (*.xml)
models_dir = "/content/models"
model_files = sorted([f for f in os.listdir(models_dir) if f.endswith(".xml")])

# Define a blacklist of keywords related to oxygen (these keywords only match as independent words)
black_list = [
    "o2",
    "o2-",
    "oxygen",
    "superoxide",
    "peroxide"
]

# Modified helper function: use regular expressions to ensure only matching independent keywords (word boundaries)
def is_oxygen_related(met_name, blacklist):
    lower_name = met_name.lower()
    for term in blacklist:
        # Use \b word boundary to match independent keywords
        if re.search(rf"\b{re.escape(term)}\b", lower_name):
            return True
    return False

# Traverse all models and merge all metabolites into a dictionary; the key is the cleaned-up ID and the value is the metabolite name.
all_mets = {}
for mf in model_files:
    model_path = os.path.join(models_dir, mf)
    try:
        model = cobra.io.read_sbml_model(model_path)
    except Exception as e:
        print(f"[Error] Failed to load model {mf}: {e}")
        continue

    # Traverse all metabolites in the current model
    for met in model.metabolites:
        # If the metabolite name contains oxygen-related keywords, skip it
        if met.compartment=='c0':
          continue
        if is_oxygen_related(met.name, black_list):
            continue
        # Remove potential "_e0" and "_c0" suffixes to get a cleaner ID
        tidy_id = met.id.replace("_e0", "").replace("_c0", "")
        # If this tidy_id is not already added, then add it to the dictionary
        if tidy_id not in all_mets:
            all_mets[tidy_id] = met.name

# Write the merged metabolites dictionary into the oxygen-free medium file
tsv_path = "complete_media_without_oxygen.tsv"
with open(tsv_path, "w") as f:
    f.write("id\tname\tconcentration\tminflux\tmaxflux\n")
    for met_id, met_name in all_mets.items():
        f.write(f"{met_id}\t{met_name}\t1\t-1000\t1000\n")

print(f"\n[Oxygen-free medium file saved] => {tsv_path}")

# ---------------------------------------------
# Now traverse all models and print the oxygen-related metabolite information,
# so that you can adjust the blacklist later if needed.
print("\n=== Checking oxygen-related metabolites in all 39 models ===")
for mf in model_files:
    model_path = os.path.join(models_dir, mf)
    try:
        model = cobra.io.read_sbml_model(model_path)
    except Exception as e:
        print(f"[Error] Failed to load model {mf}: {e}")
        continue
    print(f"\n------ Model: {mf} (ID: {model.id if model.id else 'N/A'}) ------")
    for met in model.metabolites:
        if is_oxygen_related(met.name, black_list):
            print(f"{met.name} [{met.compartment}]  => {met.id}")

print("\n[Check completed]")
# Out:
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# [Oxygen-free medium file saved] => complete_media_without_oxygen.tsv
#
# === Checking oxygen-related metabolites in all 39 models ===
#
# ------ Model: GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_000010425.1_ASM1042v1_protein.xml (ID: N/A) ------
# O2 [e0] [e0]  => cpd00007_e0
# O2 [c0] [c0]  => cpd00007_c0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
#
# ------ Model: GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063415.1_Latilactobacillus_sakei_J33_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2- [c0] [c0]  => cpd00532_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
#
# ------ Model: GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ------ Model: GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.xml (ID: N/A) ------
# O2 [c0] [c0]  => cpd00007_c0
# O2 [e0] [e0]  => cpd00007_e0
#
# [Check completed]

# %%
# !cat complete_media_without_oxygen.tsv
# Out:
# id	name	concentration	minflux	maxflux
# cpd00067	H+ [e0]	1	-1000	1000
# cpd00075	Nitrite [e0]	1	-1000	1000
# cpd11576	L-methionine R-oxide [e0]	1	-1000	1000
# cpd04097	Pb [e0]	1	-1000	1000
# cpd01030	Salicin [e0]	1	-1000	1000
# cpd01012	Cd2+ [e0]	1	-1000	1000
# cpd00276	GLUM [e0]	1	-1000	1000
# cpd00082	D-Fructose [e0]	1	-1000	1000
# cpd00058	Cu2+ [e0]	1	-1000	1000
# cpd00080	Glycerol-3-phosphate [e0]	1	-1000	1000
# cpd00314	D-Mannitol [e0]	1	-1000	1000
# cpd00222	GLCN [e0]	1	-1000	1000
# cpd00013	NH3 [e0]	1	-1000	1000
# cpd00051	L-Arginine [e0]	1	-1000	1000
# cpd00064	Ornithine [e0]	1	-1000	1000
# cpd00244	Ni2+ [e0]	1	-1000	1000
# cpd00179	Maltose [e0]	1	-1000	1000
# cpd00205	K+ [e0]	1	-1000	1000
# cpd00355	Nicotinamide ribonucleotide [e0]	1	-1000	1000
# cpd00100	Glycerol [e0]	1	-1000	1000
# cpd00009	Phosphate [e0]	1	-1000	1000
# cpd00060	L-Methionine [e0]	1	-1000	1000
# cpd00137	Citrate [e0]	1	-1000	1000
# cpd00034	Zn2+ [e0]	1	-1000	1000
# cpd00076	Sucrose [e0]	1	-1000	1000
# cpd01171	Dulcose [e0]	1	-1000	1000
# cpd00023	L-Glutamate [e0]	1	-1000	1000
# cpd00281	GABA [e0]	1	-1000	1000
# cpd00264	Spermidine [e0]	1	-1000	1000
# cpd03724	Ferrichrome [e0]	1	-1000	1000
# cpd00637	D-Methionine [e0]	1	-1000	1000
# cpd00122	N-Acetyl-D-glucosamine [e0]	1	-1000	1000
# cpd08306	Butyro-betaine [e0]	1	-1000	1000
# cpd15603	Gly-Cys [e0]	1	-1000	1000
# cpd03696	Ursin [e0]	1	-1000	1000
# cpd00208	LACT [e0]	1	-1000	1000
# cpd00118	Putrescine [e0]	1	-1000	1000
# cpd00309	XAN [e0]	1	-1000	1000
# cpd00220	Riboflavin [e0]	1	-1000	1000
# cpd00084	L-Cysteine [e0]	1	-1000	1000
# cpd00588	Sorbitol [e0]	1	-1000	1000
# cpd00138	D-Mannose [e0]	1	-1000	1000
# cpd10515	Fe2+ [e0]	1	-1000	1000
# cpd00039	L-Lysine [e0]	1	-1000	1000
# cpd00540	BET [e0]	1	-1000	1000
# cpd00971	Na+ [e0]	1	-1000	1000
# cpd00030	Mn2+ [e0]	1	-1000	1000
# cpd00149	Co2+ [e0]	1	-1000	1000
# cpd11597	ARSENOBETAINE [e0]	1	-1000	1000
# cpd01914	L-Methionine S-oxide [e0]	1	-1000	1000
# cpd00531	Hg2+ [e0]	1	-1000	1000
# cpd00027	D-Glucose [e0]	1	-1000	1000
# cpd00794	TRHL [e0]	1	-1000	1000
# cpd00105	D-Ribose [e0]	1	-1000	1000
# cpd08305	crotonobetaine [e0]	1	-1000	1000
# cpd00254	Mg [e0]	1	-1000	1000
# cpd00048	Sulfate [e0]	1	-1000	1000
# cpd00104	BIOT [e0]	1	-1000	1000
# cpd00092	Uracil [e0]	1	-1000	1000
# cpd00053	L-Glutamine [e0]	1	-1000	1000
# cpd00130	L-Malate [e0]	1	-1000	1000
# cpd00158	CELB [e0]	1	-1000	1000
# cpd01157	Chitobiose [e0]	1	-1000	1000
# cpd01757	N-Acetylmuramate [e0]	1	-1000	1000
# cpd00099	Cl- [e0]	1	-1000	1000
# cpd00180	Oxalate [e0]	1	-1000	1000
# cpd00047	Formate [e0]	1	-1000	1000
# cpd00001	H2O [e0]	1	-1000	1000
# cpd10516	fe3 [e0]	1	-1000	1000
# cpd00116	Methanol [e0]	1	-1000	1000
# cpd00011	CO2 [e0]	1	-1000	1000
# cpd03453	Enterobactin [e0]	1	-1000	1000
# cpd03726	Fe-enterochlin [e0]	1	-1000	1000
# cpd00106	Fumarate [e0]	1	-1000	1000
# cpd00108	Galactose [e0]	1	-1000	1000
# cpd00036	Succinate [e0]	1	-1000	1000
# cpd00154	Xylose [e0]	1	-1000	1000
# cpd00033	Glycine [e0]	1	-1000	1000
# cpd00012	PPi [e0]	1	-1000	1000
# cpd00129	L-Proline [e0]	1	-1000	1000
# cpd00635	Cbl [e0]	1	-1000	1000
# cpd00020	Pyruvate [e0]	1	-1000	1000
# cpd15560	Ubiquinone-8 [e0]	1	-1000	1000
# cpd15561	Ubiquinol-8 [e0]	1	-1000	1000
# cpd00073	Urea [e0]	1	-1000	1000
# cpd00063	Ca2+ [e0]	1	-1000	1000
# cpd00107	L-Leucine [e0]	1	-1000	1000
# cpd00224	L-Arabinose [e0]	1	-1000	1000
# cpd01017	Cys-Gly [e0]	1	-1000	1000
# cpd11578	hexanesulfonate [e0]	1	-1000	1000
# cpd00214	Palmitate [e0]	1	-1000	1000
# cpd00119	L-Histidine [e0]	1	-1000	1000
# cpd00654	Deoxycytidine [e0]	1	-1000	1000
# cpd11579	ethanesulfonate [e0]	1	-1000	1000
# cpd00176	2-keto-3-deoxygluconate [e0]	1	-1000	1000
# cpd00550	D-Serine [e0]	1	-1000	1000
# cpd00054	L-Serine [e0]	1	-1000	1000
# cpd00644	PAN [e0]	1	-1000	1000
# cpd00029	Acetate [e0]	1	-1000	1000
# cpd00041	L-Aspartate [e0]	1	-1000	1000
# cpd00035	L-Alanine [e0]	1	-1000	1000
# cpd00164	Glucuronate [e0]	1	-1000	1000
# cpd00132	L-Asparagine [e0]	1	-1000	1000
# cpd01092	Allantoin [e0]	1	-1000	1000
# cpd03343	Phenylpropanoate [e0]	1	-1000	1000
# cpd01262	Amylotriose [e0]	1	-1000	1000
# cpd00280	D-Galacturonate [e0]	1	-1000	1000
# cpd00028	Heme [e0]	1	-1000	1000
# cpd00117	D-Alanine [e0]	1	-1000	1000
# cpd00307	Cytosine [e0]	1	-1000	1000
# cpd00653	D-Galactonate [e0]	1	-1000	1000
# cpd00305	Thiamin [e0]	1	-1000	1000
# cpd03048	Isethionate [e0]	1	-1000	1000
# cpd11596	butanesulfonate [e0]	1	-1000	1000
# cpd00065	L-Tryptophan [e0]	1	-1000	1000
# cpd03847	Myristic acid [e0]	1	-1000	1000
# cpd00609	D-Glucarate [e0]	1	-1000	1000
# cpd04099	Phosphonate [e0]	1	-1000	1000
# cpd00024	2-Oxoglutarate [e0]	1	-1000	1000
# cpd00162	Aminoethanol [e0]	1	-1000	1000
# cpd00386	D-Malate [e0]	1	-1000	1000
# cpd03725	Fe(III)dicitrate [e0]	1	-1000	1000
# cpd00209	Nitrate [e0]	1	-1000	1000
# cpd00226	HYXN [e0]	1	-1000	1000
# cpd09878	Sulfoacetate [e0]	1	-1000	1000
# cpd00751	L-Fucose [e0]	1	-1000	1000
# cpd00268	H2S2O3 [e0]	1	-1000	1000
# cpd01329	Maltohexaose [e0]	1	-1000	1000
# cpd00069	L-Tyrosine [e0]	1	-1000	1000
# cpd00322	L-Isoleucine [e0]	1	-1000	1000
# cpd00059	L-Ascorbate [e0]	1	-1000	1000
# cpd03424	Vitamin B12 [e0]	1	-1000	1000
# cpd00098	Choline [e0]	1	-1000	1000
# cpd08023	methanesulfonate [e0]	1	-1000	1000
# cpd00156	L-Valine [e0]	1	-1000	1000
# cpd01080	ocdca [e0]	1	-1000	1000
# cpd00151	Thymine [e0]	1	-1000	1000
# cpd00396	L-Rhamnose [e0]	1	-1000	1000
# cpd00066	L-Phenylalanine [e0]	1	-1000	1000
# cpd00121	L-Inositol [e0]	1	-1000	1000
# cpd00383	Shikimate [e0]	1	-1000	1000
# cpd00128	Adenine [e0]	1	-1000	1000
# cpd00381	L-Cystine [e0]	1	-1000	1000
# cpd00042	GSH [e0]	1	-1000	1000
# cpd00166	Calomide [e0]	1	-1000	1000
# cpd00731	Ala-Ala [e0]	1	-1000	1000
# cpd04098	Arsenite [e0]	1	-1000	1000
# cpd00136	4-Hydroxybenzoate [e0]	1	-1000	1000
# cpd00182	Adenosine [e0]	1	-1000	1000
# cpd00412	Deoxyuridine [e0]	1	-1000	1000
# cpd00246	Inosine [e0]	1	-1000	1000
# cpd00367	Cytidine [e0]	1	-1000	1000
# cpd00184	Thymidine [e0]	1	-1000	1000
# cpd00797	(R)-3-Hydroxybutanoate [e0]	1	-1000	1000
# cpd00438	Deoxyadenosine [e0]	1	-1000	1000
# cpd00681	Choline sulfate [e0]	1	-1000	1000
# cpd00249	Uridine [e0]	1	-1000	1000
# cpd00277	Deoxyguanosine [e0]	1	-1000	1000
# cpd03279	Deoxyinosine [e0]	1	-1000	1000
# cpd00266	Carnitine [e0]	1	-1000	1000
# cpd00161	L-Threonine [e0]	1	-1000	1000
# cpd01155	Cadaverine [e0]	1	-1000	1000
# cpd03198	Melibiose [e0]	1	-1000	1000
# cpd00210	Taurine [e0]	1	-1000	1000
# cpd00395	L-Cysteate [e0]	1	-1000	1000
# cpd11575	MOPS [e0]	1	-1000	1000
# cpd01015	Cyanate [e0]	1	-1000	1000
# cpd00159	L-Lactate [e0]	1	-1000	1000
# cpd00870	gamma-butyrobetaine [e0]	1	-1000	1000
# cpd00308	Malonate [e0]	1	-1000	1000
# cpd00311	Guanosine [e0]	1	-1000	1000
# cpd27384	Li+ [e0]	1	-1000	1000
# cpd11595	chromate [e0]	1	-1000	1000

# %%
# Define the list of IDs to check
to_check = ["cpd00007_c0", "cpd00532_c0", "cpd00001"]

# Initialize a dictionary to record whether each ID is found
found = {key: False for key in to_check}

# Open and read the "complete_media_without_oxygen.tsv" file
tsv_path = "complete_media_without_oxygen.tsv"

with open(tsv_path, "r") as f:
    # Read all lines while skipping the header
    lines = f.readlines()[1:]
    for line in lines:
        # Split each line into fields based on the tab delimiter
        parts = line.strip().split("\t")
        if parts:
            id_val = parts[0]
            if id_val in to_check:
                found[id_val] = True

# Output the checking results
for key in to_check:
    print(f"{key}: {'Found' if found[key] else 'Not Found'}")
# Out:
# cpd00007_c0: Not Found
# cpd00532_c0: Not Found
# cpd00001: Found

# %%
from cobra import Reaction

def makeExchangeReaction(model, met):
  new_reaction = Reaction('EX_' + met.id)
  new_reaction.name = met.name + 'exchange'
  new_reaction.lower_bound = -1000
  new_reaction.upper_bound = 1000
  new_reaction.add_metabolites({
    met: -1.0})

  model.add_reactions([new_reaction])
  return model

def fix_exchange_reactions(model_in):
  for met in model_in.metabolites:
    if met.compartment == 'e0':
      if not model_in.reactions.has_id('EX_' + met.id):
        model_in = makeExchangeReaction(model_in, met)
  return model_in.copy()

# %% [markdown]
# # Gapfilling

# %%
# BLOCK X: Gapfilling all 39 models with "complete_media_without_oxygen.tsv"

# 1) First, view the first few lines of the medium file to ensure the oxygen-free medium file is correct
# !head complete_media_without_oxygen.tsv

# 2) List the files in the current directory to check if your draft models folder exists, etc.
# !ls
# !pip install dnngior --no-deps

import os
import cobra
import dnngior
import traceback

# Define input and output directories
models_dir = "/content/models"  # Folder containing 39 draft model (*.xml) files
output_dir = "/content/models_gapfilled"  # Folder to store the gapfilled models
os.makedirs(output_dir, exist_ok=True)

# Collect all model files ending with .xml
model_files = sorted([f for f in os.listdir(models_dir) if f.endswith(".xml")])

# Iterate over each model and perform gapfilling
for mf in model_files:
    model_path = os.path.join(models_dir, mf)
    prefix = mf.replace(".xml", "")
    print(f"\n=== Gapfilling {prefix} with no-oxygen medium ===")

    try:
        # Use DNNGIOR to perform gapfilling
        gapfill_no_oxygen = dnngior.Gapfill(
            model_path,
            medium_file='complete_media_without_oxygen.tsv',
            objectiveName='bio1'
        )

        # gapfilledModel contains the model after gapfilling
        model_gapfilled_no_oxygen = gapfill_no_oxygen.gapfilledModel.copy()

        model_gapfilled_no_oxygen = fix_exchange_reactions(model_gapfilled_no_oxygen)

        # -------- New step: Manually ensure that the bio1 reaction is set as the objective function --------
        try:
            bio_rxn = model_gapfilled_no_oxygen.reactions.get_by_id("bio1")
            bio_rxn.objective_coefficient = 1.0
            model_gapfilled_no_oxygen.objective = bio_rxn
            print("  [Info] 'bio1' objective function has been set with objective_coefficient = 1.0")
        except Exception as e:
            print("  [Warning] 'bio1' not found or unable to set objective_coefficient:", e)

        # Save the gapfilled model to the output folder
        out_path = os.path.join(output_dir, f"{prefix}_gapfilled_noO2.xml")
        cobra.io.write_sbml_model(model_gapfilled_no_oxygen, out_path)

        # Print the summary of the objective function to check if biomass can be produced after gapfilling
        print("Objective function (bio1) summary:")
        # First, check the optimization result before calling summary
        solution = model_gapfilled_no_oxygen.optimize()
        print("  FBA solution objective:", solution.objective_value)
        # Optionally, use model_gapfilled_no_oxygen.summary() to see a detailed flux distribution
        print(model_gapfilled_no_oxygen.summary())

        print(f"[Saved] Gapfilled model => {out_path}\n")

    except Exception as e:
        print(f"[Error] Gapfilling failed for {mf}: {e}")
        traceback.print_exc()

print("\n[All gapfilling done! Models saved in /content/models_gapfilled.]")
# Out:
# id	name	concentration	minflux	maxflux
# cpd00067	H+ [e0]	1	-1000	1000
# cpd00075	Nitrite [e0]	1	-1000	1000
# cpd11576	L-methionine R-oxide [e0]	1	-1000	1000
# cpd04097	Pb [e0]	1	-1000	1000
# cpd01030	Salicin [e0]	1	-1000	1000
# cpd01012	Cd2+ [e0]	1	-1000	1000
# cpd00276	GLUM [e0]	1	-1000	1000
# cpd00082	D-Fructose [e0]	1	-1000	1000
# cpd00058	Cu2+ [e0]	1	-1000	1000
# complete_media_without_oxygen.tsv
# GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.faa
# GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.faa
# GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.faa
# GCF_000010425.1_ASM1042v1_protein.faa
# GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.faa
# GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.faa
# GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.faa
# GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.faa
# GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.faa
# GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.faa
# GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.faa
# GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.faa
# GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.faa
# GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.faa
# GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.faa
# GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.faa
# GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.faa
# GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.faa
# GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.faa
# GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.faa
# GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.faa
# GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.faa
# GCF_964063415.1_Latilactobacillus_sakei_J33_protein.faa
# GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.faa
# GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.faa
# GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.faa
# GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.faa
# GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.faa
# GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.faa
# GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.faa
# GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.faa
# GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.faa
# GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.faa
# GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.faa
# GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.faa
# GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.faa
# GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.faa
# GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.faa
# GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.faa
# GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.faa
# genomes
# licenses
# models
# sample_data
# Collecting dnngior
#   Downloading dnngior-0.0.5-py3-none-any.whl.metadata (2.8 kB)
# Downloading dnngior-0.0.5-py3-none-any.whl (29.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 11.7 MB/s eta 0:00:00
# Installing collected packages: dnngior
# Successfully installed dnngior-0.0.5
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.11/dist-packages/dnngior/addExchanges.py:18: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   compounds_helper = Compounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/addExchanges.py:19: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   compounds_dict   = compounds_helper.loadCompounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:13: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   compounds_helper = Compounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:14: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   compounds_dict = compounds_helper.loadCompounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:16: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/Aliases/Unique_ModelSEED_Compound_Aliases.txt' mode='r' encoding='utf-8'>
#   compounds_aliases_dict = compounds_helper.loadMSAliases()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/MSEED_reactions.py:25: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   self.CompoundsHelper = Compounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/MSEED_reactions.py:26: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/compounds.tsv' mode='r' encoding='utf-8'>
#   self.Compounds_Dict  = self.CompoundsHelper.loadCompounds()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:22: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/reactions.tsv' mode='r' encoding='utf-8'>
#   reactions_helper = Reactions()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:23: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/reactions.tsv' mode='r' encoding='utf-8'>
#   reactions_dict = reactions_helper.loadReactions()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/local/lib/python3.11/dist-packages/dnngior/build_model.py:24: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.11/dist-packages/dnngior/files/biochemistry/Aliases/Unique_ModelSEED_Reaction_Aliases.txt' mode='r' encoding='utf-8'>
#   reactions_aliases_dict = reactions_helper.loadMSAliases()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# WARNING: To enable the NN_Trainer script, you need to install tensorflow <https://www.tensorflow.org/install>
# The rest of dnngior features can be used without it.
#
# === Gapfilling GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  7 / 846
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76725
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38362
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19181
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9590
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4795
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2397
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1198
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  599
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  299
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  149
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  74
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.368968.
# Read LP format model from file /tmp/tmpxgmy46mh.lp
# Reading time = 0.01 seconds
# : 988 rows, 1936 columns, 9192 nonzeros
# NN gapfilling added 122 new reactions
# The NN gapfilled model, comes with 968 reactions and 988 metabolites
# Read LP format model from file /tmp/tmpe6clmive.lp
# Reading time = 0.02 seconds
# : 988 rows, 1936 columns, 9192 nonzeros
# Read LP format model from file /tmp/tmpms9ip5hk.lp
# Reading time = 0.01 seconds
# : 988 rows, 2058 columns, 9314 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 69.52913843999997
# Objective
# =========
# 1.0 bio1 = 69.52913843999997
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00013_e0 EX_cpd00013_e0 0.2147         0  0.00%
# cpd00028_e0 EX_cpd00028_e0    0.5        34  4.98%
# cpd00030_e0 EX_cpd00030_e0    0.5         0  0.00%
# cpd00034_e0 EX_cpd00034_e0    0.5         0  0.00%
# cpd00048_e0 EX_cpd00048_e0    0.5         0  0.00%
# cpd00053_e0 EX_cpd00053_e0  0.697         5  1.02%
# cpd00058_e0 EX_cpd00058_e0    0.5         0  0.00%
# cpd00063_e0 EX_cpd00063_e0    0.5         0  0.00%
# cpd00080_e0 EX_cpd00080_e0  38.08         3 33.47%
# cpd00099_e0 EX_cpd00099_e0    0.5         0  0.00%
# cpd00104_e0 EX_cpd00104_e0    0.5        10  1.46%
# cpd00118_e0 EX_cpd00118_e0    0.5         4  0.59%
# cpd00122_e0 EX_cpd00122_e0  2.228         8  5.22%
# cpd00130_e0 EX_cpd00130_e0  10.93         4 12.81%
# cpd00166_e0 EX_cpd00166_e0    0.5        72 10.55%
# cpd00205_e0 EX_cpd00205_e0    0.5         0  0.00%
# cpd00220_e0 EX_cpd00220_e0      1        17  4.98%
# cpd00254_e0 EX_cpd00254_e0    0.5         0  0.00%
# cpd00264_e0 EX_cpd00264_e0    0.5         7  1.03%
# cpd00276_e0 EX_cpd00276_e0   7.97         6 14.01%
# cpd00305_e0 EX_cpd00305_e0    0.5        12  1.76%
# cpd00355_e0 EX_cpd00355_e0 0.2225        11  0.72%
# cpd00540_e0 EX_cpd00540_e0 0.1667         5  0.24%
# cpd10516_e0 EX_cpd10516_e0    0.5         0  0.00%
# cpd15560_e0 EX_cpd15560_e0    0.5        49  7.18%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00027_e0 EX_cpd00027_e0  -10.3         6 68.82%
# cpd00067_e0 EX_cpd00067_e0   -158         0  0.00%
# cpd00092_e0 EX_cpd00092_e0     -1         4  4.45%
# cpd03422_e0 EX_cpd03422_e0   -0.5        48 26.73%
# cpd11416_c0 SK_cpd11416_c0 -69.53         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2.xml
#
#
# === Gapfilling GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic with no-oxygen medium ===
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  12 / 1475
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75663
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37831
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18915
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9457
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4728
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2364
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1182
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  591
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  295
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  147
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  73
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  36
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.071892.
# Read LP format model from file /tmp/tmphlz6bnam.lp
# Reading time = 0.01 seconds
# : 1376 rows, 3086 columns, 14282 nonzeros
# NN gapfilling added 68 new reactions
# The NN gapfilled model, comes with 1543 reactions and 1376 metabolites
# Read LP format model from file /tmp/tmpo2dnlrm2.lp
# Reading time = 0.01 seconds
# : 1376 rows, 3086 columns, 14282 nonzeros
# Read LP format model from file /tmp/tmp5bwrryxb.lp
# Reading time = 0.01 seconds
# : 1376 rows, 3338 columns, 14534 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 4.019054225806446
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Objective
# =========
# 1.0 bio1 = 4.019054225806446
#
# Uptake
# ------
#  Metabolite       Reaction     Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0    32.18         0  0.00%
# cpd00028_e0 EX_cpd00028_e0  0.01127        34  0.96%
# cpd00030_e0 EX_cpd00030_e0  0.01127         0  0.00%
# cpd00034_e0 EX_cpd00034_e0  0.01127         0  0.00%
# cpd00058_e0 EX_cpd00058_e0  0.01127         0  0.00%
# cpd00060_e0 EX_cpd00060_e0 0.008767         5  0.11%
# cpd00063_e0 EX_cpd00063_e0  0.01127         0  0.00%
# cpd00080_e0 EX_cpd00080_e0    3.935         3 29.42%
# cpd00098_e0 EX_cpd00098_e0   0.1636         5  2.04%
# cpd00099_e0 EX_cpd00099_e0  0.01127         0  0.00%
# cpd00104_e0 EX_cpd00104_e0  0.01127        10  0.28%
# cpd00118_e0 EX_cpd00118_e0  0.01127         4  0.11%
# cpd00129_e0 EX_cpd00129_e0    1.326         5 16.53%
# cpd00205_e0 EX_cpd00205_e0  0.01127         0  0.00%
# cpd00254_e0 EX_cpd00254_e0  0.01127         0  0.00%
# cpd00264_e0 EX_cpd00264_e0  0.01127         7  0.20%
# cpd00305_e0 EX_cpd00305_e0  0.01127        12  0.34%
# cpd00383_e0 EX_cpd00383_e0  0.01571         7  0.27%
# cpd01080_e0 EX_cpd01080_e0        1        18 44.86%
# cpd03847_e0 EX_cpd03847_e0   0.1005        14  3.51%
# cpd10515_e0 EX_cpd10515_e0  0.02254         0  0.00%
# cpd10516_e0 EX_cpd10516_e0  0.01127         0  0.00%
# cpd15560_e0 EX_cpd15560_e0  0.01127        49  1.38%
#
# Secretion
# ---------
#  Metabolite       Reaction     Flux  C-Number C-Flux
# cpd00009_e0 EX_cpd00009_e0   -7.145         0  0.00%
# cpd00011_e0 EX_cpd00011_e0   -16.69         1 26.67%
# cpd00013_e0 EX_cpd00013_e0   -2.592         0  0.00%
# cpd00024_e0 EX_cpd00024_e0    -1.39         5 11.10%
# cpd00029_e0 EX_cpd00029_e0   -16.22         2 51.82%
# cpd00033_e0 EX_cpd00033_e0  -0.2451         2  0.78%
# cpd00092_e0 EX_cpd00092_e0  -0.4613         4  2.95%
# cpd00117_e0 EX_cpd00117_e0  -0.3015         3  1.45%
# cpd00307_e0 EX_cpd00307_e0  -0.8048         4  5.14%
# cpd00355_e0 EX_cpd00355_e0 -0.00501        11  0.09%
# cpd11416_c0 SK_cpd11416_c0   -4.019         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2.xml
#
#
# === Gapfilling GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  7 / 707
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76994
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38497
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19248
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9624
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4812
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2406
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1203
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  601
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.083235.
# Read LP format model from file /tmp/tmprp3zfkgl.lp
# Reading time = 0.01 seconds
# : 860 rows, 1700 columns, 8000 nonzeros
# NN gapfilling added 143 new reactions
# The NN gapfilled model, comes with 850 reactions and 860 metabolites
# Read LP format model from file /tmp/tmpihd37qo1.lp
# Reading time = 0.02 seconds
# : 860 rows, 1700 columns, 8000 nonzeros
# Read LP format model from file /tmp/tmp7u0er9zo.lp
# Reading time = 0.01 seconds
# : 860 rows, 1804 columns, 8104 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 69.52913843999997
# Objective
# =========
# 1.0 bio1 = 69.52913843999997
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00028_e0 EX_cpd00028_e0    0.5        34  0.79%
# cpd00030_e0 EX_cpd00030_e0    0.5         0  0.00%
# cpd00034_e0 EX_cpd00034_e0    0.5         0  0.00%
# cpd00039_e0 EX_cpd00039_e0      1         6  0.28%
# cpd00058_e0 EX_cpd00058_e0    0.5         0  0.00%
# cpd00063_e0 EX_cpd00063_e0    0.5         0  0.00%
# cpd00067_e0 EX_cpd00067_e0   1000         0  0.00%
# cpd00092_e0 EX_cpd00092_e0  2.379         4  0.44%
# cpd00099_e0 EX_cpd00099_e0    0.5         0  0.00%
# cpd00104_e0 EX_cpd00104_e0    0.5        10  0.23%
# cpd00118_e0 EX_cpd00118_e0    0.5         4  0.09%
# cpd00119_e0 EX_cpd00119_e0 0.2147         6  0.06%
# cpd00166_e0 EX_cpd00166_e0    0.5        72  1.67%
# cpd00205_e0 EX_cpd00205_e0    0.5         0  0.00%
# cpd00220_e0 EX_cpd00220_e0      1        17  0.79%
# cpd00254_e0 EX_cpd00254_e0    0.5         0  0.00%
# cpd00264_e0 EX_cpd00264_e0    0.5         7  0.16%
# cpd00276_e0 EX_cpd00276_e0  282.3         6 78.60%
# cpd00305_e0 EX_cpd00305_e0    0.5        12  0.28%
# cpd00309_e0 EX_cpd00309_e0  64.75         5 15.02%
# cpd00322_e0 EX_cpd00322_e0 0.5258         6  0.15%
# cpd00540_e0 EX_cpd00540_e0 0.3333         5  0.08%
# cpd01914_e0 EX_cpd01914_e0  0.288         5  0.07%
# cpd10515_e0 EX_cpd10515_e0    1.5         0  0.00%
# cpd15560_e0 EX_cpd15560_e0    0.5        49  1.14%
# cpd15603_e0 EX_cpd15603_e0 0.6698         5  0.16%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00027_e0 EX_cpd00027_e0 -265.7         6 35.00%
# cpd00122_e0 EX_cpd00122_e0 -335.8         8 58.99%
# cpd02229_e0 EX_cpd02229_e0 -4.536        55  5.48%
# cpd03422_e0 EX_cpd03422_e0   -0.5        48  0.53%
# cpd11416_c0 SK_cpd11416_c0 -69.53         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_000010425.1_ASM1042v1_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  7 / 664
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  77068
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38534
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19267
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9633
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4816
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2408
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1204
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  602
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  301
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.047198.
# Read LP format model from file /tmp/tmpr0ajy809.lp
# Reading time = 0.01 seconds
# : 820 rows, 1642 columns, 7810 nonzeros
# NN gapfilling added 157 new reactions
# The NN gapfilled model, comes with 821 reactions and 820 metabolites
# Read LP format model from file /tmp/tmpe8xw14ym.lp
# Reading time = 0.01 seconds
# : 820 rows, 1642 columns, 7810 nonzeros
# Read LP format model from file /tmp/tmpk89qticu.lp
# Reading time = 0.01 seconds
# : 820 rows, 1736 columns, 7904 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 69.52913843999997
# Objective
# =========
# 1.0 bio1 = 69.52913843999997
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00009_e0 EX_cpd00009_e0  1.333         0  0.00%
# cpd00013_e0 EX_cpd00013_e0  21.99         0  0.00%
# cpd00027_e0 EX_cpd00027_e0  11.48         6  2.95%
# cpd00028_e0 EX_cpd00028_e0    0.5        34  0.73%
# cpd00030_e0 EX_cpd00030_e0    0.5         0  0.00%
# cpd00034_e0 EX_cpd00034_e0    0.5         0  0.00%
# cpd00051_e0 EX_cpd00051_e0      1         6  0.26%
# cpd00058_e0 EX_cpd00058_e0    0.5         0  0.00%
# cpd00060_e0 EX_cpd00060_e0 0.4973         5  0.11%
# cpd00063_e0 EX_cpd00063_e0    0.5         0  0.00%
# cpd00065_e0 EX_cpd00065_e0 0.3128        11  0.15%
# cpd00067_e0 EX_cpd00067_e0   1000         0  0.00%
# cpd00069_e0 EX_cpd00069_e0 0.3203         9  0.12%
# cpd00099_e0 EX_cpd00099_e0    0.5         0  0.00%
# cpd00104_e0 EX_cpd00104_e0    0.5        10  0.21%
# cpd00119_e0 EX_cpd00119_e0 0.3561         6  0.09%
# cpd00156_e0 EX_cpd00156_e0  1.462         5  0.31%
# cpd00166_e0 EX_cpd00166_e0    0.5        72  1.54%
# cpd00205_e0 EX_cpd00205_e0    0.5         0  0.00%
# cpd00220_e0 EX_cpd00220_e0      1        17  0.73%
# cpd00254_e0 EX_cpd00254_e0    0.5         0  0.00%
# cpd00264_e0 EX_cpd00264_e0    0.5         7  0.15%
# cpd00276_e0 EX_cpd00276_e0  348.9         6 89.56%
# cpd00305_e0 EX_cpd00305_e0    0.5        12  0.26%
# cpd01017_e0 EX_cpd01017_e0 0.7492         5  0.16%
# cpd01329_e0 EX_cpd01329_e0  1.063        36  1.64%
# cpd10515_e0 EX_cpd10515_e0      1         0  0.00%
# cpd10516_e0 EX_cpd10516_e0    0.5         0  0.00%
# cpd15560_e0 EX_cpd15560_e0    0.5        49  1.05%
#
# Secretion
# ---------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00122_e0 EX_cpd00122_e0 -348.2         8 98.00%
# cpd00129_e0 EX_cpd00129_e0 -6.568         5  1.16%
# cpd03422_e0 EX_cpd03422_e0   -0.5        48  0.84%
# cpd11416_c0 SK_cpd11416_c0 -69.53         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  6 / 770
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76867
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38433
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19216
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9608
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4804
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2402
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1201
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  600
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.011353.
# Read LP format model from file /tmp/tmpul44kne1.lp
# Reading time = 0.02 seconds
# : 951 rows, 1818 columns, 8550 nonzeros
# NN gapfilling added 139 new reactions
# The NN gapfilled model, comes with 909 reactions and 951 metabolites
# Read LP format model from file /tmp/tmpxpqjfgjg.lp
# Reading time = 0.01 seconds
# : 951 rows, 1818 columns, 8550 nonzeros
# Read LP format model from file /tmp/tmpvppqlb8e.lp
# Reading time = 0.01 seconds
# : 951 rows, 1936 columns, 8668 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 69.52913843999997
# Objective
# =========
# 1.0 bio1 = 69.52913843999997
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0  95.18         0  0.00%
# cpd00028_e0 EX_cpd00028_e0    0.5        34  1.52%
# cpd00030_e0 EX_cpd00030_e0    0.5         0  0.00%
# cpd00034_e0 EX_cpd00034_e0    0.5         0  0.00%
# cpd00041_e0 EX_cpd00041_e0  14.35         4  5.12%
# cpd00051_e0 EX_cpd00051_e0  67.89         6 36.32%
# cpd00054_e0 EX_cpd00054_e0  13.47         3  3.60%
# cpd00058_e0 EX_cpd00058_e0    0.5         0  0.00%
# cpd00063_e0 EX_cpd00063_e0    0.5         0  0.00%
# cpd00099_e0 EX_cpd00099_e0    0.5         0  0.00%
# cpd00104_e0 EX_cpd00104_e0    0.5        10  0.45%
# cpd00117_e0 EX_cpd00117_e0      1         3  0.27%
# cpd00205_e0 EX_cpd00205_e0    0.5         0  0.00%
# cpd00208_e0 EX_cpd00208_e0     20        12 21.40%
# cpd00220_e0 EX_cpd00220_e0      1        17  1.52%
# cpd00226_e0 EX_cpd00226_e0 0.5299         5  0.24%
# cpd00254_e0 EX_cpd00254_e0    0.5         0  0.00%
# cpd00264_e0 EX_cpd00264_e0    0.5         7  0.31%
# cpd00305_e0 EX_cpd00305_e0    0.5        12  0.53%
# cpd00307_e0 EX_cpd00307_e0  2.278         4  0.81%
# cpd00309_e0 EX_cpd00309_e0  3.162         5  1.41%
# cpd00540_e0 EX_cpd00540_e0 0.2175         5  0.10%
# cpd00635_e0 EX_cpd00635_e0    0.5        62  2.76%
# cpd00794_e0 EX_cpd00794_e0     20        12 21.40%
# cpd15560_e0 EX_cpd15560_e0    0.5        49  2.18%
# cpd15603_e0 EX_cpd15603_e0 0.1752         5  0.08%
#
# Secretion
# ---------
#  Metabolite       Reaction    Flux  C-Number C-Flux
# cpd00023_e0 EX_cpd00023_e0   -1000         5 33.18%
# cpd00024_e0 EX_cpd00024_e0  -566.8         5 18.81%
# cpd00027_e0 EX_cpd00027_e0  -617.3         6 24.58%
# cpd00033_e0 EX_cpd00033_e0  -447.7         2  5.94%
# cpd00039_e0 EX_cpd00039_e0 -0.8262         6  0.03%
# cpd00064_e0 EX_cpd00064_e0  -67.89         5  2.25%
# cpd00066_e0 EX_cpd00066_e0 -0.3347         9  0.02%
# cpd00108_e0 EX_cpd00108_e0     -20         6  0.80%
# cpd00119_e0 EX_cpd00119_e0 -0.2984         6  0.01%
# cpd00122_e0 EX_cpd00122_e0  -267.2         8 14.19%
# cpd00508_e0 EX_cpd00508_e0 -0.4728         6  0.02%
# cpd03422_e0 EX_cpd03422_e0    -0.5        48  0.16%
# cpd11416_c0 SK_cpd11416_c0  -69.53         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  7 / 912
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76594
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38297
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19148
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9574
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4787
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2393
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1196
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  598
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  299
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  149
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  74
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.065248.
# Read LP format model from file /tmp/tmpv92tmbjd.lp
# Reading time = 0.01 seconds
# : 1027 rows, 2078 columns, 9708 nonzeros
# NN gapfilling added 127 new reactions
# The NN gapfilled model, comes with 1039 reactions and 1027 metabolites
# Read LP format model from file /tmp/tmpxi161q36.lp
# Reading time = 0.02 seconds
# : 1027 rows, 2078 columns, 9708 nonzeros
# Read LP format model from file /tmp/tmp2epef3wx.lp
# Reading time = 0.01 seconds
# : 1027 rows, 2238 columns, 9868 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 69.52913843999997
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Objective
# =========
# 1.0 bio1 = 69.52913843999997
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0  214.2         0  0.00%
# cpd00028_e0 EX_cpd00028_e0    0.5        34 13.66%
# cpd00030_e0 EX_cpd00030_e0    0.5         0  0.00%
# cpd00034_e0 EX_cpd00034_e0    0.5         0  0.00%
# cpd00058_e0 EX_cpd00058_e0    0.5         0  0.00%
# cpd00063_e0 EX_cpd00063_e0    0.5         0  0.00%
# cpd00099_e0 EX_cpd00099_e0    0.5         0  0.00%
# cpd00104_e0 EX_cpd00104_e0    0.5        10  4.02%
# cpd00118_e0 EX_cpd00118_e0    0.5         4  1.61%
# cpd00166_e0 EX_cpd00166_e0    0.5        72 28.92%
# cpd00180_e0 EX_cpd00180_e0      2         2  3.21%
# cpd00184_e0 EX_cpd00184_e0 0.5305        10  4.26%
# cpd00205_e0 EX_cpd00205_e0    0.5         0  0.00%
# cpd00220_e0 EX_cpd00220_e0      1        17 13.66%
# cpd00254_e0 EX_cpd00254_e0    0.5         0  0.00%
# cpd00264_e0 EX_cpd00264_e0    0.5         7  2.81%
# cpd00305_e0 EX_cpd00305_e0    0.5        12  4.82%
# cpd00540_e0 EX_cpd00540_e0 0.3333         5  1.34%
# cpd10515_e0 EX_cpd10515_e0      1         0  0.00%
# cpd10516_e0 EX_cpd10516_e0    0.5         0  0.00%
# cpd15560_e0 EX_cpd15560_e0    0.5        49 19.68%
# cpd15603_e0 EX_cpd15603_e0    0.5         5  2.01%
#
# Secretion
# ---------
#  Metabolite       Reaction    Flux  C-Number C-Flux
# cpd00009_e0 EX_cpd00009_e0  -333.3         0  0.00%
# cpd00013_e0 EX_cpd00013_e0  -93.69         0  0.00%
# cpd00024_e0 EX_cpd00024_e0  -169.3         5 27.29%
# cpd00027_e0 EX_cpd00027_e0  -166.4         6 32.18%
# cpd00033_e0 EX_cpd00033_e0  -1.833         2  0.12%
# cpd00047_e0 EX_cpd00047_e0      -2         1  0.06%
# cpd00092_e0 EX_cpd00092_e0  -110.1         4 14.20%
# cpd00100_e0 EX_cpd00100_e0 -0.7474         3  0.07%
# cpd00117_e0 EX_cpd00117_e0  -118.8         3 11.49%
# cpd00122_e0 EX_cpd00122_e0  -53.56         8 13.81%
# cpd03422_e0 EX_cpd03422_e0    -0.5        48  0.77%
# cpd11416_c0 SK_cpd11416_c0  -69.53         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  6 / 708
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76975
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38487
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19243
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9621
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4810
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2405
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1202
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  601
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.352619.
# Read LP format model from file /tmp/tmp_bn4757o.lp
# Reading time = 0.01 seconds
# : 913 rows, 1702 columns, 7966 nonzeros
# NN gapfilling added 143 new reactions
# The NN gapfilled model, comes with 851 reactions and 913 metabolites
# Read LP format model from file /tmp/tmpxbgax0f1.lp
# Reading time = 0.01 seconds
# : 913 rows, 1702 columns, 7966 nonzeros
# Read LP format model from file /tmp/tmp6mzchud4.lp
# Reading time = 0.01 seconds
# : 913 rows, 1810 columns, 8074 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 4.897447379757583
# Objective
# =========
# 1.0 bio1 = 4.897447379757583
#
# Uptake
# ------
#  Metabolite       Reaction     Flux  C-Number C-Flux
# cpd00028_e0 EX_cpd00028_e0  0.03522        34 10.75%
# cpd00030_e0 EX_cpd00030_e0  0.03522         0  0.00%
# cpd00034_e0 EX_cpd00034_e0  0.03522         0  0.00%
# cpd00054_e0 EX_cpd00054_e0 0.007428         3  0.20%
# cpd00058_e0 EX_cpd00058_e0  0.03522         0  0.00%
# cpd00063_e0 EX_cpd00063_e0  0.03522         0  0.00%
# cpd00099_e0 EX_cpd00099_e0  0.03522         0  0.00%
# cpd00104_e0 EX_cpd00104_e0  0.03522        10  3.16%
# cpd00117_e0 EX_cpd00117_e0        1         3 26.94%
# cpd00118_e0 EX_cpd00118_e0  0.03522         4  1.27%
# cpd00166_e0 EX_cpd00166_e0  0.03522        72 22.77%
# cpd00205_e0 EX_cpd00205_e0  0.03522         0  0.00%
# cpd00220_e0 EX_cpd00220_e0  0.07044        17 10.75%
# cpd00254_e0 EX_cpd00254_e0  0.03522         0  0.00%
# cpd00264_e0 EX_cpd00264_e0  0.03522         7  2.21%
# cpd00305_e0 EX_cpd00305_e0  0.03522        12  3.80%
# cpd00540_e0 EX_cpd00540_e0  0.02348         5  1.05%
# cpd15560_e0 EX_cpd15560_e0  0.03522        49 15.50%
# cpd15603_e0 EX_cpd15603_e0  0.03522         5  1.58%
#
# Secretion
# ---------
#  Metabolite       Reaction      Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0   -0.5442         0  0.00%
# cpd00011_e0 EX_cpd00011_e0    -0.188         1  1.76%
# cpd00013_e0 EX_cpd00013_e0 -0.002805         0  0.00%
# cpd00027_e0 EX_cpd00027_e0    -1.216         6 68.09%
# cpd00033_e0 EX_cpd00033_e0   -0.1177         2  2.20%
# cpd00067_e0 EX_cpd00067_e0    -1.497         0  0.00%
# cpd00122_e0 EX_cpd00122_e0    -0.163         8 12.17%
# cpd03422_e0 EX_cpd03422_e0  -0.03522        48 15.78%
# cpd11416_c0 SK_cpd11416_c0    -4.897         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  6 / 653
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  77016
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38508
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19254
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9627
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4813
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2406
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1203
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  601
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.350954.
# Read LP format model from file /tmp/tmpm0xy2g_b.lp
# Reading time = 0.01 seconds
# : 853 rows, 1598 columns, 7638 nonzeros
# NN gapfilling added 146 new reactions
# The NN gapfilled model, comes with 799 reactions and 853 metabolites
# Read LP format model from file /tmp/tmpi33l7fm2.lp
# Reading time = 0.01 seconds
# : 853 rows, 1598 columns, 7638 nonzeros
# Read LP format model from file /tmp/tmp3bnr8deo.lp
# Reading time = 0.01 seconds
# : 853 rows, 1704 columns, 7744 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 46.35275895999998
# Objective
# =========
# 1.0 bio1 = 46.35275895999998
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00028_e0 EX_cpd00028_e0 0.3333        34 10.97%
# cpd00030_e0 EX_cpd00030_e0 0.3333         0  0.00%
# cpd00034_e0 EX_cpd00034_e0 0.3333         0  0.00%
# cpd00058_e0 EX_cpd00058_e0 0.3333         0  0.00%
# cpd00063_e0 EX_cpd00063_e0 0.3333         0  0.00%
# cpd00082_e0 EX_cpd00082_e0 0.6288         6  3.65%
# cpd00099_e0 EX_cpd00099_e0 0.3333         0  0.00%
# cpd00104_e0 EX_cpd00104_e0 0.3333        10  3.23%
# ...
# cpd00007_e0 EX_cpd00007_e0  -0.5363         0  0.00%
# cpd00011_e0 EX_cpd00011_e0  -0.1553         1  4.26%
# cpd00033_e0 EX_cpd00033_e0 -0.01454         2  0.80%
# cpd00041_e0 EX_cpd00041_e0 -0.08431         4  9.24%
# cpd00054_e0 EX_cpd00054_e0 -0.04416         3  3.63%
# cpd00067_e0 EX_cpd00067_e0   -1.951         0  0.00%
# cpd00122_e0 EX_cpd00122_e0   -0.163         8 35.74%
# cpd03422_e0 EX_cpd03422_e0 -0.03522        48 46.34%
# cpd11416_c0 SK_cpd11416_c0   -4.897         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  7 / 723
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76926
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38463
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19231
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9615
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4807
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2403
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1201
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  600
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.023895.
# Read LP format model from file /tmp/tmp890cv0nh.lp
# Reading time = 0.01 seconds
# : 901 rows, 1722 columns, 8084 nonzeros
# NN gapfilling added 138 new reactions
# The NN gapfilled model, comes with 861 reactions and 901 metabolites
# Read LP format model from file /tmp/tmpg_r3bb51.lp
# Reading time = 0.01 seconds
# : 901 rows, 1722 columns, 8084 nonzeros
# Read LP format model from file /tmp/tmpe5ssncdb.lp
# Reading time = 0.01 seconds
# : 901 rows, 1838 columns, 8200 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 46.35275895999998
# Objective
# =========
# 1.0 bio1 = 46.35275895999998
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0  481.7         0  0.00%
# cpd00013_e0 EX_cpd00013_e0  8.118         0  0.00%
# cpd00028_e0 EX_cpd00028_e0 0.3333        34  0.11%
# cpd00030_e0 EX_cpd00030_e0 0.3333         0  0.00%
# cpd00034_e0 EX_cpd00034_e0 0.3333         0  0.00%
# cpd00058_e0 EX_cpd00058_e0 0.3333         0  0.00%
# cpd00063_e0 EX_cpd00063_e0 0.3333         0  0.00%
# cpd00099_e0 EX_cpd00099_e0 0.3333         0  0.00%
# cpd00104_e0 EX_cpd00104_e0 0.3333        10  0.03%
# cpd00118_e0 EX_cpd00118_e0 0.3333         4  0.01%
# cpd00166_e0 EX_cpd00166_e0 0.3333        72  0.24%
# cpd00205_e0 EX_cpd00205_e0 0.3333         0  0.00%
# cpd00220_e0 EX_cpd00220_e0 0.6667        17  0.11%
# cpd00254_e0 EX_cpd00254_e0 0.3333         0  0.00%
# cpd00264_e0 EX_cpd00264_e0 0.3333         7  0.02%
# cpd00276_e0 EX_cpd00276_e0  459.8         6 27.38%
# cpd00305_e0 EX_cpd00305_e0 0.3333        12  0.04%
# cpd00794_e0 EX_cpd00794_e0  603.5        12 71.87%
# cpd10516_e0 EX_cpd10516_e0      1         0  0.00%
# cpd15560_e0 EX_cpd15560_e0 0.3333        49  0.16%
# cpd15603_e0 EX_cpd15603_e0 0.3333         5  0.02%
#
# Secretion
# ---------
#  Metabolite       Reaction    Flux  C-Number C-Flux
# cpd00001_e0 EX_cpd00001_e0   -1000         0  0.00%
# cpd00011_e0 EX_cpd00011_e0  -442.7         1  4.45%
# cpd00027_e0 EX_cpd00027_e0  -374.3         6 22.60%
# cpd00033_e0 EX_cpd00033_e0 -0.3333         2  0.01%
# cpd00092_e0 EX_cpd00092_e0 -0.2003         4  0.01%
# cpd00122_e0 EX_cpd00122_e0  -460.5         8 37.07%
# cpd00138_e0 EX_cpd00138_e0  -590.6         6 35.65%
# cpd01757_e0 EX_cpd01757_e0      -1        11  0.11%
# cpd03422_e0 EX_cpd03422_e0 -0.2222        48  0.11%
# cpd11416_c0 SK_cpd11416_c0  -46.35         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  6 / 672
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  77047
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38523
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19261
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9630
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4815
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2407
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1203
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  601
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  300
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  150
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  75
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.006026.
# Read LP format model from file /tmp/tmpp8fhuwk5.lp
# Reading time = 0.01 seconds
# : 809 rows, 1586 columns, 7494 nonzeros
# NN gapfilling added 121 new reactions
# The NN gapfilled model, comes with 793 reactions and 809 metabolites
# Read LP format model from file /tmp/tmpxw1ci99c.lp
# Reading time = 0.01 seconds
# : 809 rows, 1586 columns, 7494 nonzeros
# Read LP format model from file /tmp/tmpz994jjmv.lp
# Reading time = 0.01 seconds
# : 809 rows, 1686 columns, 7594 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 46.35275895999998
# Objective
# =========
# 1.0 bio1 = 46.35275895999998
#
# Uptake
# ------
#  Metabolite       Reaction   Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0  322.8         0  0.00%
# cpd00028_e0 EX_cpd00028_e0 0.3333        34  5.15%
# cpd00030_e0 EX_cpd00030_e0 0.3333         0  0.00%
# cpd00034_e0 EX_cpd00034_e0 0.3333         0  0.00%
# cpd00058_e0 EX_cpd00058_e0 0.3333         0  0.00%
# cpd00063_e0 EX_cpd00063_e0 0.3333         0  0.00%
# cpd00099_e0 EX_cpd00099_e0 0.3333         0  0.00%
# cpd00104_e0 EX_cpd00104_e0 0.3333        10  1.51%
# cpd00118_e0 EX_cpd00118_e0 0.3333         4  0.61%
# cpd00166_e0 EX_cpd00166_e0 0.3333        72 10.91%
# cpd00205_e0 EX_cpd00205_e0 0.3333         0  0.00%
# cpd00220_e0 EX_cpd00220_e0 0.6667        17  5.15%
# cpd00254_e0 EX_cpd00254_e0 0.3333         0  0.00%
# cpd00264_e0 EX_cpd00264_e0 0.3333         7  1.06%
# cpd00276_e0 EX_cpd00276_e0  10.82         6 29.49%
# cpd00305_e0 EX_cpd00305_e0 0.3333        12  1.82%
# cpd00309_e0 EX_cpd00309_e0      1         5  2.27%
# cpd00540_e0 EX_cpd00540_e0 0.2222         5  0.50%
# cpd00794_e0 EX_cpd00794_e0  6.115        12 33.35%
# cpd10516_e0 EX_cpd10516_e0      1         0  0.00%
# cpd15560_e0 EX_cpd15560_e0 0.3333        49  7.42%
# cpd15603_e0 EX_cpd15603_e0 0.3333         5  0.76%
#
# Secretion
# ---------
#  Metabolite       Reaction    Flux  C-Number C-Flux
# cpd00011_e0 EX_cpd00011_e0  -728.6         1 83.70%
# cpd00013_e0 EX_cpd00013_e0  -1.449         0  0.00%
# cpd02229_e0 EX_cpd02229_e0  -2.289        55 14.46%
# cpd03422_e0 EX_cpd03422_e0 -0.3333        48  1.84%
# cpd11416_c0 SK_cpd11416_c0  -46.35         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2.xml
#
#
# === Gapfilling GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein with no-oxygen medium ===
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# ERROR:cobra.io.sbml:'' is not a valid SBML 'SId'.
# Gap-filling database =  ModelSEED
# ERROR:cobra.io.sbml:No objective coefficients in model. Unclear what should be optimized
# Loading medium from: complete_media_without_oxygen.tsv
# #reactions not found in NN-keys:  8 / 812
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Flux through biomass reaction is 1.00000000
# Flux through biomass reaction is 1.00000000
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  76792
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  38396
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  19198
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9599
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  4799
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2399
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1199
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  599
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  299
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  149
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  74
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  37
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  18
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  9
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  5
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  3
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  2
#
#
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
#
#
#  condition is currently:  1
#
#
# Objective value is 0.052171.
# Read LP format model from file /tmp/tmp5woyv2bg.lp
# Reading time = 0.01 seconds
# : 942 rows, 1868 columns, 8848 nonzeros
# NN gapfilling added 122 new reactions
# The NN gapfilled model, comes with 934 reactions and 942 metabolites
# Read LP format model from file /tmp/tmp_ufz3r3q.lp
# Reading time = 0.01 seconds
# : 942 rows, 1868 columns, 8848 nonzeros
# Read LP format model from file /tmp/tmppitz8vlx.lp
# Reading time = 0.01 seconds
# : 942 rows, 2008 columns, 8988 nonzeros
#   [Info] 'bio1' objective function has been set with objective_coefficient = 1.0
# Objective function (bio1) summary:
#   FBA solution objective: 4.897447379757582
# Objective
# =========
# 1.0 bio1 = 4.897447379757582
#
# Uptake
# ------
#  Metabolite       Reaction    Flux  C-Number C-Flux
# cpd00007_e0 EX_cpd00007_e0  0.5551         0  0.00%
# cpd00028_e0 EX_cpd00028_e0 0.03522        34  6.69%
# cpd00030_e0 EX_cpd00030_e0 0.03522         0  0.00%
# cpd00034_e0 EX_cpd00034_e0 0.03522         0  0.00%
# cpd00054_e0 EX_cpd00054_e0  0.2772         3  4.65%
# cpd00058_e0 EX_cpd00058_e0 0.03522         0  0.00%
# cpd00063_e0 EX_cpd00063_e0 0.03522         0  0.00%
# cpd00067_e0 EX_cpd00067_e0   150.5         0  0.00%
# cpd00099_e0 EX_cpd00099_e0 0.03522         0  0.00%
# cpd00104_e0 EX_cpd00104_e0 0.03522        10  1.97%
# cpd00117_e0 EX_cpd00117_e0       1         3 16.77%
# cpd00118_e0 EX_cpd00118_e0 0.03522         4  0.79%
# cpd00166_e0 EX_cpd00166_e0 0.03522        72 14.17%
# cpd00205_e0 EX_cpd00205_e0 0.03522         0  0.00%
# cpd00220_e0 EX_cpd00220_e0 0.07044        17  6.69%
# cpd00254_e0 EX_cpd00254_e0 0.03522         0  0.00%
# cpd00264_e0 EX_cpd00264_e0 0.03522         7  1.38%
# cpd00276_e0 EX_cpd00276_e0   1.011         6 33.90%
# cpd00305_e0 EX_cpd00305_e0 0.03522        12  2.36%
# cpd10516_e0 EX_cpd10516_e0 0.03522         0  0.00%
# cpd15560_e0 EX_cpd15560_e0 0.03522        49  9.64%
# cpd15603_e0 EX_cpd15603_e0 0.03522         5  0.98%
#
# Secretion
# ---------
#  Metabolite       Reaction     Flux  C-Number C-Flux
# cpd00023_e0 EX_cpd00023_e0   -0.165         5  0.09%
# cpd00027_e0 EX_cpd00027_e0   -159.1         6 99.58%
# cpd00033_e0 EX_cpd00033_e0  -0.3359         2  0.07%
# cpd00098_e0 EX_cpd00098_e0 -0.05375         5  0.03%
# cpd00122_e0 EX_cpd00122_e0  -0.0667         8  0.06%
# cpd03422_e0 EX_cpd03422_e0 -0.03522        48  0.18%
# cpd11416_c0 SK_cpd11416_c0   -4.897         0  0.00%
#
# [Saved] Gapfilled model => /content/models_gapfilled/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2.xml
#
#
# [All gapfilling done! Models saved in /content/models_gapfilled.]

# %% [markdown]
# **Extract & Unify Exchange Reactions from All Gapfilled Models**

# %%
import os
import cobra
import numpy as np

gapfilled_dir = "/content/models_gapfilled"  # folder containing 39 gapfilled models
model_files = sorted([f for f in os.listdir(gapfilled_dir) if f.endswith(".xml")])

def extract_exchange_reactions(model):
    """
    Return a dictionary of exchange reactions from the model
    that have negative lower_bound (< 0), i.e., import direction.

    Format: {rxn_id: [met_id, met_name, met_formula]}
    """
    exchange_reactions = {}
    for reaction in model.reactions:
        # Common practice: exchange rxns often start with "EX_",
        # but you can adapt this filter if your exchange IDs differ
        if reaction.id.startswith("EX_") and (reaction.lower_bound < 0):
            # Typically there's only 1 metabolite in an exchange reaction,
            # so we grab the first one
            if len(reaction.metabolites) == 1:
                met = list(reaction.metabolites.keys())[0]
                exchange_reactions[reaction.id] = [met.id, met.name, met.formula]

    return exchange_reactions

# 1) Collect exchange reactions from each gapfilled model
all_exchange_dict = {}  # key=rxn_id, value=[met_id, met_name, met_formula]

for mf in model_files:
    model_path = os.path.join(gapfilled_dir, mf)
    print(f"Extracting exchange rxns from {mf}...")
    try:
        model = cobra.io.read_sbml_model(model_path)
    except Exception as e:
        print(f"[Error] Cannot load {mf}: {e}")
        continue

    ex_rxns = extract_exchange_reactions(model)

    # Unify them
    for rxn_id, info_list in ex_rxns.items():
        if rxn_id not in all_exchange_dict:
            all_exchange_dict[rxn_id] = info_list

# 2) Write the unified exchange reactions to a file
medium_file = "group_medium_exchanges.tsv"
with open(medium_file, "w") as f:
    f.write("rxn_id\tmet_id\tmet_name\tmet_formula\n")
    for rxn_id, info in all_exchange_dict.items():
        met_id, met_name, met_form = info
        f.write(f"{rxn_id}\t{met_id}\t{met_name}\t{met_form}\n")

print(f"\n[Unified exchange reactions saved to: {medium_file}]")
print(f"Total unique exchange reactions: {len(all_exchange_dict)}")
# Out:
# Extracting exchange rxns from GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2.xml...
# Extracting exchange rxns from GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2.xml...
# Extracting exchange rxns from GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063385.1_Latilactobacillus_curvatus_J116_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063415.1_Latilactobacillus_sakei_J33_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2.xml...
# Extracting exchange rxns from GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2.xml...
#
# [Unified exchange reactions saved to: group_medium_exchanges.tsv]
# Total unique exchange reactions: 175

# %% [markdown]
# **Apply the Unified Exchange List to All Gapfilled Models**

# %%
import random

def apply_medium(model, medium_dict, optimize=True):
    """
    Given a dictionary of {rxn_id: flux_value}, set the reaction lower_bound in the model.
    E.g., if flux_value = 5 then reaction.lower_bound = -5 (for import direction).
    """
    for rxn_id, flux_value in medium_dict.items():
        if rxn_id in model.reactions:
            rxn = model.reactions.get_by_id(rxn_id)
            rxn.lower_bound = -flux_value
    if optimize:
        sol = model.optimize()
        return sol
    return None

# 1) Read the unified exchange list from the file
ex_file = "group_medium_exchanges.tsv"  # Note: File name has been changed to "group_medium_exchanges.tsv" if needed
exchange_list = []
with open(ex_file, "r") as f:
    lines = f.read().strip().split("\n")[1:]  # Skip header
    for line in lines:
        rxn_id, met_id, met_name, met_formula = line.split("\t")
        exchange_list.append(rxn_id)

# 2) Build a dictionary of flux values for each exchange.
# For demonstration, we pick random flux bounds in the range [0, 10] for each reaction.
medium_dict = {}
for rxn_id in exchange_list:
    medium_dict[rxn_id] = random.uniform(0, 10)

# 3) Apply this "medium" to each gapfilled model.
for mf in model_files:
    model_path = os.path.join(gapfilled_dir, mf)
    prefix = mf.replace(".xml", "")
    print(f"\nApplying medium to {prefix}...")

    try:
        model = cobra.io.read_sbml_model(model_path)
    except Exception as e:
        print(f"[Error] Loading {mf}: {e}")
        continue

    # Apply the new exchange flux bounds
    solution = apply_medium(model, medium_dict, optimize=True)
    if solution:
        print(f"  After applying medium, objective = {solution.objective_value}")
    else:
        print("  No solution returned.")

    # (Optional) Save the updated model if desired
    out_path = os.path.join(gapfilled_dir, f"{prefix}_appliedMedium.xml")
    cobra.io.write_sbml_model(model, out_path)
    print(f"  => Updated model saved: {out_path}")
# Out:
# Applying medium to GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 13.977121869796349
#   => Updated model saved: /content/models_gapfilled/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 81.40794593343111
#   => Updated model saved: /content/models_gapfilled/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 109.7991149817285
#   => Updated model saved: /content/models_gapfilled/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 50.15673364102333
#   => Updated model saved: /content/models_gapfilled/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 242.27674620200298
#   => Updated model saved: /content/models_gapfilled/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 13.977121869796349
#   => Updated model saved: /content/models_gapfilled/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 13.977121869796349
#   => Updated model saved: /content/models_gapfilled/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 19.435980802684135
#   => Updated model saved: /content/models_gapfilled/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 9.158507916739993
#   => Updated model saved: /content/models_gapfilled/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 168.65701353294
#   => Updated model saved: /content/models_gapfilled/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063385.1_Latilactobacillus_curvatus_J116_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 9.899589719492198
#   => Updated model saved: /content/models_gapfilled/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063415.1_Latilactobacillus_sakei_J33_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063415.1_Latilactobacillus_sakei_J33_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 93.91365696291967
#   => Updated model saved: /content/models_gapfilled/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 0.0
#   => Updated model saved: /content/models_gapfilled/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 0.0
#   => Updated model saved: /content/models_gapfilled/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml
#
# Applying medium to GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2_appliedMedium...
#   After applying medium, objective = 12.175685452659103
#   => Updated model saved: /content/models_gapfilled/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2_appliedMedium_appliedMedium.xml

# %%
# !zip -r /content/content.zip /content
from google.colab import files
files.download("/content/content.zip")
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2025.04.21/ (stored 0%)
#   adding: content/.config/logs/2025.04.21/18.42.22.411154.log (deflated 58%)
#   adding: content/.config/logs/2025.04.21/18.42.31.744939.log (deflated 56%)
#   adding: content/.config/logs/2025.04.21/18.42.12.824329.log (deflated 58%)
#   adding: content/.config/logs/2025.04.21/18.42.21.235934.log (deflated 86%)
#   adding: content/.config/logs/2025.04.21/18.42.31.045496.log (deflated 57%)
#   adding: content/.config/logs/2025.04.21/18.41.51.884422.log (deflated 92%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 24%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.faa (deflated 49%)
#   adding: content/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.faa (deflated 47%)
#   adding: content/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.faa (deflated 47%)
#   adding: content/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.faa (deflated 49%)
#   adding: content/complete_media_without_oxygen.tsv (deflated 76%)
#   adding: content/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.faa (deflated 48%)
#   adding: content/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.faa (deflated 48%)
#   adding: content/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.faa (deflated 47%)
#   adding: content/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.faa (deflated 47%)
#   adding: content/models/ (stored 0%)
#   adding: content/models/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.xml (deflated 94%)
#   adding: content/models/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.xml (deflated 94%)
#   adding: content/models/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.xml (deflated 94%)
#   adding: content/models/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.xml (deflated 94%)
#   adding: content/models/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.xml (deflated 94%)
#   adding: content/models/GCF_000010425.1_ASM1042v1_protein.xml (deflated 94%)
#   adding: content/models/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.xml (deflated 94%)
#   adding: content/models/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.xml (deflated 94%)
#   adding: content/models/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.xml (deflated 94%)
#   adding: content/models/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.xml (deflated 94%)
#   adding: content/models/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.xml (deflated 94%)
#   adding: content/models/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.xml (deflated 94%)
#   adding: content/models/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.xml (deflated 94%)
#   adding: content/models/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.xml (deflated 94%)
#   adding: content/models/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.xml (deflated 94%)
#   adding: content/models/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.xml (deflated 94%)
#   adding: content/models/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063415.1_Latilactobacillus_sakei_J33_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.xml (deflated 94%)
#   adding: content/models/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.xml (deflated 94%)
#   adding: content/models/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.xml (deflated 94%)
#   adding: content/models/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.xml (deflated 94%)
#   adding: content/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.faa (deflated 54%)
#   adding: content/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.faa (deflated 47%)
#   adding: content/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.faa (deflated 48%)
#   adding: content/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.faa (deflated 48%)
#   adding: content/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.faa (deflated 48%)
#   adding: content/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.faa (deflated 48%)
#   adding: content/GCF_964063415.1_Latilactobacillus_sakei_J33_protein.faa (deflated 47%)
#   adding: content/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.faa (deflated 47%)
#   adding: content/models_gapfilled/ (stored 0%)
#   adding: content/models_gapfilled/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_000010425.1_ASM1042v1_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063415.1_Latilactobacillus_sakei_J33_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063415.1_Latilactobacillus_sakei_J33_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein_gapfilled_noO2.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein_gapfilled_noO2_appliedMedium.xml (deflated 94%)
#   adding: content/models_gapfilled/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein_gapfilled_noO2_appliedMedium.xml (deflated 95%)
#   adding: content/models_gapfilled/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein_gapfilled_noO2.xml (deflated 95%)
#   adding: content/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.faa (deflated 48%)
#   adding: content/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.faa (deflated 47%)
#   adding: content/group_medium_exchanges.tsv (deflated 69%)
#   adding: content/licenses/ (stored 0%)
#   adding: content/licenses/gurobi.lic (deflated 9%)
#   adding: content/GCF_000010425.1_ASM1042v1_protein.faa (deflated 47%)
#   adding: content/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.faa (deflated 47%)
#   adding: content/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.faa (deflated 47%)
#   adding: content/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.faa (deflated 48%)
#   adding: content/genomes/ (stored 0%)
#   adding: content/genomes/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_000010425.1_ASM1042v1_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065095.1_Lentilactobacillus_buchneri_CIRM-BIA2511_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062975.1_Lactococcus_lactis_CIRM-BIA2553_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062635.1_Pediococcus_ethanolidurans_CIRM-BIA2669_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065235.1_Leuconostoc_pseudomesenteroides_CIRM-BIA2446_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063415.1_Latilactobacillus_sakei_J33_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964084875.1_Leuconostoc_carnosum_A1b-VegA_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.fna.gz (deflated 0%)
#   adding: content/genomes/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063385.1_Latilactobacillus_curvatus_J116_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063345.1_Pseudomonas_lini_CIRM-BIA2854_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065435.1_Pediococcus_parvulus_CIRM-BIA2501_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065165.1_Levilactobacillus_yonginensis_CIRM-BIA2544_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCA_964062575.1_Lactococcus_lactis_CIRM-BIA2698_genomic.fna.gz (deflated 0%)
#   adding: content/genomes/GCF_964065285.1_Levilactobacillus_brevis_CIRM-BIA2444_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.fna.gz (deflated 0%)
#   adding: content/genomes/GCF_964063405.1_Leuconostoc_mesenteroides_FLEC04_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065465.1_Liquorilactobacillus_satsumensis_CIRM-BIA2521_protein.faa.gz (deflated 0%)
#   adding: content/genomes/.git/ (stored 0%)
#   adding: content/genomes/.git/packed-refs (deflated 9%)
#   adding: content/genomes/.git/logs/ (stored 0%)
#   adding: content/genomes/.git/logs/refs/ (stored 0%)
#   adding: content/genomes/.git/logs/refs/heads/ (stored 0%)
#   adding: content/genomes/.git/logs/refs/heads/main (deflated 28%)
#   adding: content/genomes/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/genomes/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/genomes/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: content/genomes/.git/logs/HEAD (deflated 28%)
#   adding: content/genomes/.git/hooks/ (stored 0%)
#   adding: content/genomes/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/genomes/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/genomes/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/genomes/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/genomes/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/genomes/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/genomes/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/genomes/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/genomes/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/genomes/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/genomes/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/genomes/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/genomes/.git/hooks/update.sample (deflated 68%)
#   adding: content/genomes/.git/branches/ (stored 0%)
#   adding: content/genomes/.git/refs/ (stored 0%)
#   adding: content/genomes/.git/refs/heads/ (stored 0%)
#   adding: content/genomes/.git/refs/heads/main (stored 0%)
#   adding: content/genomes/.git/refs/tags/ (stored 0%)
#   adding: content/genomes/.git/refs/remotes/ (stored 0%)
#   adding: content/genomes/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/genomes/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/genomes/.git/index (deflated 56%)
#   adding: content/genomes/.git/objects/ (stored 0%)
#   adding: content/genomes/.git/objects/pack/ (stored 0%)
#   adding: content/genomes/.git/objects/pack/pack-31569a34a92687e02698758725c59d78ed6c5a66.pack (deflated 0%)
#   adding: content/genomes/.git/objects/pack/pack-31569a34a92687e02698758725c59d78ed6c5a66.idx (deflated 34%)
#   adding: content/genomes/.git/objects/info/ (stored 0%)
#   adding: content/genomes/.git/config (deflated 33%)
#   adding: content/genomes/.git/description (deflated 14%)
#   adding: content/genomes/.git/HEAD (stored 0%)
#   adding: content/genomes/.git/info/ (stored 0%)
#   adding: content/genomes/.git/info/exclude (deflated 28%)
#   adding: content/genomes/GCF_964069135.1_Schleiferilactobacillus_harbinensis_CIRM-BIA2388_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063155.1_Pediococcus_parvulus_IOEB-9646_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062525.1_Enterococcus_gilvus_CIRM-BIA2700_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065205.1_Lacticaseibacillus_paracasei_CIRM-BIA2373_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063395.1_Pediococcus_parvulus_F2-sp2-RGJ_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.faa.gz (deflated 0%)
#   adding: content/genomes/.ipynb_checkpoints/ (stored 0%)
#   adding: content/genomes/GCF_964063315.1_Leuconostoc_carnosum_CIRM-BIA2809_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.faa.gz (deflated 0%)
#   adding: content/genomes/GCF_964060345.1_Lentilactobacillus_buchneri_CIRM-BIA1514_protein.faa.gz (deflated 0%)
#   adding: content/GCF_964063325.1_Hafnia_alvei_CIRM-BIA2718_protein.faa (deflated 45%)
#   adding: content/GCA_964063365.1_Rahnella_aquatiliss_CIRM-BIA2795_genomic.faa (deflated 52%)
#   adding: content/GCF_964063355.1_Latilactobacillus_curvatus_CIRM-BIA2781_protein.faa (deflated 48%)
#   adding: content/GCF_964065115.1_Levilactobacillus_brevis_CIRM-BIA2515_protein.faa (deflated 48%)
#   adding: content/GCA_964063435.1_Leuconostoc_mesenteroides_FME302_genomic.faa (deflated 53%)
#   adding: content/GCF_964062605.1_Lentilactobacillus_kefiri_CIRM-BIA2556_protein.faa (deflated 48%)
#   adding: content/GCF_964084915.1_Lactiplantibacillus_plantarum_ATCC14431_protein.faa (deflated 48%)
#   adding: content/GCF_964062735.1_Lentilactobacillus_parabuchneri_CIRM-BIA2637_protein.faa (deflated 48%)
#   adding: content/GCF_964063375.1_Bacillus_pumilus_CIRM-BIA2784_protein.faa (deflated 47%)
#   adding: content/GCF_964063755.1_Latilactobacillus_sakei_CIRM-BIA1912_protein.faa (deflated 48%)
#   adding: content/GCF_964063425.1_Lactiplantibacillus_pentosus_CNRZ1547_protein.faa (deflated 49%)
#   adding: content/GCF_964065245.1_Lactiplantibacillus_plantarum_CIRM-BIA2443_protein.faa (deflated 49%)
#   adding: content/GCF_964063445.1_Pediococcus_parvulus_IOEB-8801_protein.faa (deflated 47%)
#   adding: content/GCF_964068245.1_Lentilactobacillus_kefiri_CIRM-BIA2539_protein.faa (deflated 47%)
#   adding: content/GCF_964062745.1_Levilactobacillus_cerevisiae_CIRM-BIA2671_protein.faa (deflated 49%)
#   adding: content/GCF_964062795.1_Loigolactobacillus_coryniformis_CIRM-BIA2685_protein.faa (deflated 49%)
#   adding: content/GCF_964065445.1_Lactiplantibacillus_plantarum_CIRM-BIA2453_protein.faa (deflated 49%)
#   adding: content/GCF_964063335.1_Hafnia_alvei_CIRM-BIA2828_protein.faa (deflated 46%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
# <frozen importlib._bootstrap>:1047: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:1047: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
